# %% [markdown]
# Encoding 1 day candles for 5 days and doing rag - as a test

# %%
import yfinance as yf
dat = yf.Ticker("SPY")

# %%
data = dat.history( period="10y", interval="1d")

# %%
dat.info
# Out:
# {'longBusinessSummary': 'The Trust seeks to achieve its investment objective by holding a portfolio of the common stocks that are included in the index (the “Portfolio”), with the weight of each stock in the Portfolio substantially corresponding to the weight of such stock in the index.',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 593.67,
#  'open': 593.66,
#  'dayLow': 593.1525,
#  'dayHigh': 596.15,
#  'regularMarketPreviousClose': 593.67,
#  'regularMarketOpen': 593.66,
#  'regularMarketDayLow': 593.1525,
#  'regularMarketDayHigh': 596.15,
#  'trailingPE': 29.998507,
#  'volume': 31458755,
#  'regularMarketVolume': 31458755,
#  'averageVolume': 45870201,
#  'averageVolume10days': 46424620,
#  'averageDailyVolume10Day': 46424620,
#  'bid': 596.44,
#  'ask': 596.25,
#  'bidSize': 1000,
#  'askSize': 1000,
#  'yield': 0.0123000005,
#  'totalAssets': 585431908352,
#  'fiftyTwoWeekLow': 453.34,
#  'fiftyTwoWeekHigh': 600.17,
#  'fiftyDayAverage': 579.3492,
#  'twoHundredDayAverage': 542.3898,
#  'trailingAnnualDividendRate': 5.662,
#  'trailingAnnualDividendYield': 0.009537285,
#  'navPrice': 595.6956,
#  'currency': 'USD',
#  'category': 'Large Blend',
#  'ytdReturn': 0.2647403,
#  'beta3Year': 1.0,
#  'fundFamily': 'SPDR State Street Global Advisors',
#  'fundInceptionDate': 727660800,
#  'legalType': 'Exchange Traded Fund',
#  'threeYearAverageReturn': 0.1000873,
#  'fiveYearAverageReturn': 0.15664239,
#  'exchange': 'PCX',
#  'quoteType': 'ETF',
#  'symbol': 'SPY',
#  'underlyingSymbol': 'SPY',
#  'shortName': 'SPDR S&P 500',
#  'longName': 'SPDR S&P 500 ETF Trust',
#  'firstTradeDateEpochUtc': 728317800,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'uuid': 'e97de790-7e95-3762-8917-c59fcab3735e',
#  'messageBoardId': 'finmb_6160262',
#  'gmtOffSetMilliseconds': -18000000,
#  'trailingPegRatio': None}

# %%
avgVol = dat.info['averageVolume']

def applyVolumeNormalizedVectorized(row):
    row['VolumeNormalized'] = (row['Volume'] - avgVol) / avgVol
    return row


data = data.apply(applyVolumeNormalizedVectorized, axis=1)
data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2014-11-24 00:00:00-05:00  173.681967  173.866406  173.463999  173.757416
# 2014-11-25 00:00:00-05:00  173.992139  174.201728  173.371765  173.631653
# 2014-11-26 00:00:00-05:00  173.782590  174.176618  173.564622  174.076019
# 2014-11-28 00:00:00-05:00  173.950238  174.268804  173.463990  173.707108
# 2014-12-01 00:00:00-05:00  173.036409  173.153778  172.181297  172.499863
# ...                               ...         ...         ...         ...
# 2024-11-18 00:00:00-05:00  586.219971  589.489990  585.340027  588.150024
# 2024-11-19 00:00:00-05:00  584.710022  591.039978  584.030029  590.299988
# 2024-11-20 00:00:00-05:00  590.380005  590.789978  584.630005  590.500000
# 2024-11-21 00:00:00-05:00  593.400024  595.119995  587.450012  593.669983
# 2024-11-22 00:00:00-05:00  593.659973  596.150024  593.150024  595.510010
#
#                                 Volume  Dividends  Stock Splits  \
# Date
# 2014-11-24 00:00:00-05:00   65880800.0        0.0           0.0
# 2014-11-25 00:00:00-05:00   79108300.0        0.0           0.0
# 2014-11-26 00:00:00-05:00   62167800.0        0.0           0.0
# 2014-11-28 00:00:00-05:00   57890100.0        0.0           0.0
# 2014-12-01 00:00:00-05:00  103968400.0        0.0           0.0
# ...                                ...        ...           ...
# 2024-11-18 00:00:00-05:00   37084100.0        0.0           0.0
# 2024-11-19 00:00:00-05:00   49412000.0        0.0           0.0
# 2024-11-20 00:00:00-05:00   50032600.0        0.0           0.0
# 2024-11-21 00:00:00-05:00   46750300.0        0.0           0.0
# 2024-11-22 00:00:00-05:00   38092800.0        0.0           0.0
#
#                            Capital Gains  VolumeNormalized
# Date
# 2014-11-24 00:00:00-05:00            0.0          0.436244
# 2014-11-25 00:00:00-05:00            0.0          0.724612
# 2014-11-26 00:00:00-05:00            0.0          0.355298
# 2014-11-28 00:00:00-05:00            0.0          0.262042
# 2014-12-01 00:00:00-05:00            0.0          1.266578
# ...                                  ...               ...
# 2024-11-18 00:00:00-05:00            0.0         -0.191543
# 2024-11-19 00:00:00-05:00            0.0          0.077214
# 2024-11-20 00:00:00-05:00            0.0          0.090743
# 2024-11-21 00:00:00-05:00            0.0          0.019187
# 2024-11-22 00:00:00-05:00            0.0         -0.169552
#
# [2517 rows x 9 columns]

# %%
avgMovement = (data['Close']-data['Open']).mean()


def applyMovementNormalized(row):
    row['MovemementNormalize'] = (row['Close'] - row['Open']) / avgMovement
    return row


data = data.apply(applyMovementNormalized, axis=1)
data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2014-11-24 00:00:00-05:00  173.681967  173.866406  173.463999  173.757416
# 2014-11-25 00:00:00-05:00  173.992139  174.201728  173.371765  173.631653
# 2014-11-26 00:00:00-05:00  173.782590  174.176618  173.564622  174.076019
# 2014-11-28 00:00:00-05:00  173.950238  174.268804  173.463990  173.707108
# 2014-12-01 00:00:00-05:00  173.036409  173.153778  172.181297  172.499863
# ...                               ...         ...         ...         ...
# 2024-11-18 00:00:00-05:00  586.219971  589.489990  585.340027  588.150024
# 2024-11-19 00:00:00-05:00  584.710022  591.039978  584.030029  590.299988
# 2024-11-20 00:00:00-05:00  590.380005  590.789978  584.630005  590.500000
# 2024-11-21 00:00:00-05:00  593.400024  595.119995  587.450012  593.669983
# 2024-11-22 00:00:00-05:00  593.659973  596.150024  593.150024  595.510010
#
#                                 Volume  Dividends  Stock Splits  \
# Date
# 2014-11-24 00:00:00-05:00   65880800.0        0.0           0.0
# 2014-11-25 00:00:00-05:00   79108300.0        0.0           0.0
# 2014-11-26 00:00:00-05:00   62167800.0        0.0           0.0
# 2014-11-28 00:00:00-05:00   57890100.0        0.0           0.0
# 2014-12-01 00:00:00-05:00  103968400.0        0.0           0.0
# ...                                ...        ...           ...
# 2024-11-18 00:00:00-05:00   37084100.0        0.0           0.0
# 2024-11-19 00:00:00-05:00   49412000.0        0.0           0.0
# 2024-11-20 00:00:00-05:00   50032600.0        0.0           0.0
# 2024-11-21 00:00:00-05:00   46750300.0        0.0           0.0
# 2024-11-22 00:00:00-05:00   38092800.0        0.0           0.0
#
#                            Capital Gains  VolumeNormalized  \
# Date
# 2014-11-24 00:00:00-05:00            0.0          0.436244
# 2014-11-25 00:00:00-05:00            0.0          0.724612
# 2014-11-26 00:00:00-05:00            0.0          0.355298
# 2014-11-28 00:00:00-05:00            0.0          0.262042
# 2014-12-01 00:00:00-05:00            0.0          1.266578
# ...                                  ...               ...
# 2024-11-18 00:00:00-05:00            0.0         -0.191543
# 2024-11-19 00:00:00-05:00            0.0          0.077214
# 2024-11-20 00:00:00-05:00            0.0          0.090743
# 2024-11-21 00:00:00-05:00            0.0          0.019187
# 2024-11-22 00:00:00-05:00            0.0         -0.169552
#
#                            MovemementNormalize
# Date
# 2014-11-24 00:00:00-05:00             1.508151
# 2014-11-25 00:00:00-05:00            -7.205780
# 2014-11-26 00:00:00-05:00             5.865373
# 2014-11-28 00:00:00-05:00            -4.859938
# 2014-12-01 00:00:00-05:00           -10.725053
# ...                                        ...
# 2024-11-18 00:00:00-05:00            38.579934
# 2024-11-19 00:00:00-05:00           111.738089
# 2024-11-20 00:00:00-05:00             2.398588
# 2024-11-21 00:00:00-05:00             5.396213
# 2024-11-22 00:00:00-05:00            36.980469
#
# [2517 rows x 10 columns]
